# %% [markdown]
# <a href="https://colab.research.google.com/github/5ficzag/Python/blob/main/Colaboration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
data = pd.read_csv('/content/drive/My Drive/tablica.csv')
data
# Out:
#   Username;Login email;Identifier;First name;Last name
# 0     booker12;rachel@example.com;9012;Rachel;Booker
# 1                            grey07;;2070;Laura;Grey
# 2                      johnson81;;4081;Craig;Johnson
# 3       jenkins46;mary@example.com;9346;Mary;Jenkins
# 4         smith79;jamie@example.com;5079;Jamie;Smith

# %%
# !wget https://colab.research.google.com/github/5ficzag/Python/vjezba.ipynb
# Out:
# --2024-10-23 06:00:21--  https://colab.research.google.com/github/5ficzag/Python/vjezba.ipynb
# Resolving colab.research.google.com (colab.research.google.com)... 216.239.32.180, 216.239.34.180, 216.239.36.180, ...
# Connecting to colab.research.google.com (colab.research.google.com)|216.239.32.180|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘vjezba.ipynb’
#
# vjezba.ipynb            [ <=>                ]  88.39K  --.-KB/s    in 0.04s
#
# 2024-10-23 06:00:21 (2.11 MB/s) - ‘vjezba.ipynb’ saved [90516]
